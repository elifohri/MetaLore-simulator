# %% [markdown]
# # Demonstrating `mobile-env:smart-city`
#
# `mobile-env` is a simple and open environment for training, testing, and evaluating a decentralized metaverse environment.
#
# * `mobile-env:smart-city` is written in pure Python
# * It allows simulating various scenarios with moving users in a cellular network with a single base station and multiple stationary sensors
# * `mobile-env:smart-city` implements the standard [Gymnasium](https://gymnasium.farama.org/) (previously [OpenAI Gym](https://gym.openai.com/)) interface such that it can be used with all common frameworks for reinforcement learning
# * `mobile-env:smart-city` is not restricted to reinforcement learning approaches but can also be used with conventional control approaches or dummy benchmark algorithms
# * It can be configured easily (e.g., adjusting number and movement of users, properties of cells, etc.)
# * It is also easy to extend `mobile-env:smart-city`, e.g., implementing different observations, actions, or reward
#
# As such `mobile-env:smart-city` is a simple platform to test RL algorithms in a decentralized metaverse environment.

# %% [markdown]
# **Demonstration Steps:**
#
# This demonstration consists of the following steps:
#
# 1. Installation and usage of `mobile-env` with dummy actions
# 2. Configuration of `mobile-env` and adjustment of the observation space (optional)
# 3. Training a single-agent reinforcement learning approach with [`stable-baselines3`](https://github.com/DLR-RM/stable-baselines3)

# %%
# First, install stable baselines; only SB3 v2.0.0+ supports Gymnasium
# %pip install stable-baselines3==2.0.0 tensorboard
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: stable-baselines3==2.0.0 in /Users/elifohri/Library/Python/3.9/lib/python/site-packages (2.0.0)
# Requirement already satisfied: tensorboard in /Users/elifohri/Library/Python/3.9/lib/python/site-packages (2.18.0)
# Requirement already satisfied: numpy>=1.20 in /Users/elifohri/Library/Python/3.9/lib/python/site-packages (from stable-baselines3==2.0.0) (2.0.2)
# Requirement already satisfied: cloudpickle in /Users/elifohri/Library/Python/3.9/lib/python/site-packages (from stable-baselines3==2.0.0) (3.1.0)
# Requirement already satisfied: gymnasium==0.28.1 in /Users/elifohri/Library/Python/3.9/lib/python/site-packages (from stable-baselines3==2.0.0) (0.28.1)
# Requirement already satisfied: matplotlib in /Users/elifohri/Library/Python/3.9/lib/python/site-packages (from stable-baselines3==2.0.0) (3.9.3)
# Requirement already satisfied: pandas in /Users/elifohri/Library/Python/3.9/lib/python/site-packages (from stable-baselines3==2.0.0) (2.2.3)
# Requirement already satisfied: torch>=1.11 in /Users/elifohri/Library/Python/3.9/lib/python/site-packages (from stable-baselines3==2.0.0) (2.5.1)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Users/elifohri/Library/Python/3.9/lib/python/site-packages (from gymnasium==0.28.1->stable-baselines3==2.0.0) (0.0.4)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/elifohri/Library/Python/3.9/lib/python/site-packages (from gymnasium==0.28.1->stable-baselines3==2.0.0) (4.12.2)
# Requirement already satisfied: jax-jumpy>=1.0.0 in /Users/elifohri/Library/Python/3.9/lib/python/site-packages (from gymnasium==0.28.1->stable-baselines3==2.0.0) (1.0.0)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /Users/elifohri/Library/Python/3.9/lib/python/site-packages (from gymnasium==0.28.1->stable-baselines3==2.0.0) (8.5.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/elifohri/Library/Python/3.9/lib/python/site-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/elifohri/Library/Python/3.9/lib/python/site-packages (from tensorboard) (3.1.3)
# Requirement already satisfied: absl-py>=0.4 in /Users/elifohri/Library/Python/3.9/lib/python/site-packages (from tensorboard) (2.1.0)
# Requirement already satisfied: six>1.9 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from tensorboard) (1.15.0)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /Users/elifohri/Library/Python/3.9/lib/python/site-packages (from tensorboard) (5.29.1)
# Requirement already satisfied: markdown>=2.6.8 in /Users/elifohri/Library/Python/3.9/lib/python/site-packages (from tensorboard) (3.7)
# Requirement already satisfied: packaging in /Users/elifohri/Library/Python/3.9/lib/python/site-packages (from tensorboard) (24.2)
# Requirement already satisfied: grpcio>=1.48.2 in /Users/elifohri/Library/Python/3.9/lib/python/site-packages (from tensorboard) (1.68.1)
# Requirement already satisfied: setuptools>=41.0.0 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from tensorboard) (58.0.4)
# Requirement already satisfied: zipp>=3.20 in /Users/elifohri/Library/Python/3.9/lib/python/site-packages (from importlib-metadata>=4.8.0->gymnasium==0.28.1->stable-baselines3==2.0.0) (3.21.0)
# Requirement already satisfied: fsspec in /Users/elifohri/Library/Python/3.9/lib/python/site-packages (from torch>=1.11->stable-baselines3==2.0.0) (2024.10.0)
# Requirement already satisfied: jinja2 in /Users/elifohri/Library/Python/3.9/lib/python/site-packages (from torch>=1.11->stable-baselines3==2.0.0) (3.1.4)
# Requirement already satisfied: networkx in /Users/elifohri/Library/Python/3.9/lib/python/site-packages (from torch>=1.11->stable-baselines3==2.0.0) (3.2.1)
# Requirement already satisfied: sympy==1.13.1 in /Users/elifohri/Library/Python/3.9/lib/python/site-packages (from torch>=1.11->stable-baselines3==2.0.0) (1.13.1)
# Requirement already satisfied: filelock in /Users/elifohri/Library/Python/3.9/lib/python/site-packages (from torch>=1.11->stable-baselines3==2.0.0) (3.16.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/elifohri/Library/Python/3.9/lib/python/site-packages (from sympy==1.13.1->torch>=1.11->stable-baselines3==2.0.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/elifohri/Library/Python/3.9/lib/python/site-packages (from werkzeug>=1.0.1->tensorboard) (3.0.2)
# Requirement already satisfied: cycler>=0.10 in /Users/elifohri/Library/Python/3.9/lib/python/site-packages (from matplotlib->stable-baselines3==2.0.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/elifohri/Library/Python/3.9/lib/python/site-packages (from matplotlib->stable-baselines3==2.0.0) (4.55.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/elifohri/Library/Python/3.9/lib/python/site-packages (from matplotlib->stable-baselines3==2.0.0) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/elifohri/Library/Python/3.9/lib/python/site-packages (from matplotlib->stable-baselines3==2.0.0) (6.4.5)
# Requirement already satisfied: pillow>=8 in /Users/elifohri/Library/Python/3.9/lib/python/site-packages (from matplotlib->stable-baselines3==2.0.0) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/elifohri/Library/Python/3.9/lib/python/site-packages (from matplotlib->stable-baselines3==2.0.0) (3.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/elifohri/Library/Python/3.9/lib/python/site-packages (from matplotlib->stable-baselines3==2.0.0) (1.3.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/elifohri/Library/Python/3.9/lib/python/site-packages (from matplotlib->stable-baselines3==2.0.0) (1.4.7)
# Requirement already satisfied: pytz>=2020.1 in /Users/elifohri/Library/Python/3.9/lib/python/site-packages (from pandas->stable-baselines3==2.0.0) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/elifohri/Library/Python/3.9/lib/python/site-packages (from pandas->stable-baselines3==2.0.0) (2024.2)
# WARNING: You are using pip version 21.2.4; however, version 24.3.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
# Importing necessary libraries
import gymnasium
import mobile_env
import numpy as np
from stable_baselines3 import PPO
from stable_baselines3.ppo import MlpPolicy
from stable_baselines3.common.env_checker import check_env

# predefined small scenarios
from mobile_env.scenarios.smart_city import MComSmartCity

# easy access to the default configuration
MComSmartCity.default_config()
# Out:
# {'width': 200,
#  'height': 200,
#  'EP_MAX_TIME': 100,
#  'seed': 666,
#  'reset_rng_episode': False,
#  'arrival': mobile_env.core.arrival.NoDeparture,
#  'channel': mobile_env.core.channels.OkumuraHata,
#  'scheduler': mobile_env.core.schedules.ResourceFair,
#  'movement': mobile_env.core.movement.RandomWaypointMovement,
#  'utility': mobile_env.core.utilities.BoundedLogUtility,
#  'handler': mobile_env.handlers.smart_city_handler.MComSmartCityHandler,
#  'bs': {'bw': 100000000.0,
#   'freq': 2500,
#   'tx': 40,
#   'height': 50,
#   'computational_power': 100},
#  'ue': {'velocity': 1.5, 'snr_tr': 2e-08, 'noise': 1e-09, 'height': 1.5},
#  'sensor': {'height': 1.5, 'snr_tr': 2e-08, 'noise': 1e-09},
#  'ue_job': {'job_generation_probability': 0.7,
#   'communication_job_lambda_value': 10.0,
#   'computation_job_lambda_value': 10.0},
#  'sensor_job': {'communication_job_lambda_value': 5.0,
#   'computation_job_lambda_value': 5.0},
#  'e2e_delay_threshold': 3.0,
#  'reward_calculation': {'ue_penalty': -5.0,
#   'discount_factor': 0.95,
#   'base_reward': 10.0,
#   'positive_discount_factor': 0.9,
#   'negative_discount_factor': 0.8},
#  'arrival_params': {'ep_time': 100, 'reset_rng_episode': False},
#  'channel_params': {},
#  'scheduler_params': {'quantum': 2.0},
#  'movement_params': {'width': 200, 'height': 200, 'reset_rng_episode': False},
#  'utility_params': {'lower': -20, 'upper': 20, 'coeffs': (10, 0, 10)},
#  'metrics': {'scalar_metrics': {},
#   'kpi_metrics': {},
#   'ue_metrics': {},
#   'bs_metrics': {},
#   'ss_metrics': {}}}

# %%
from stable_baselines3 import PPO
from stable_baselines3.ppo import MlpPolicy
import gymnasium as gym

env = gym.make("mobile-smart_city-smart_city_handler-v0", render_mode="rgb_array")

# train PPO agent on environment. this takes a while
model = PPO(MlpPolicy, env, tensorboard_log='results_sb', verbose=1)
model.learn(total_timesteps=100000)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to results_sb/PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -637     |
# | time/              |          |
# |    fps             | 86       |
# |    iterations      | 1        |
# |    time_elapsed    | 23       |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -598         |
# | time/                   |              |
# |    fps                  | 92           |
# |    iterations           | 2            |
# |    time_elapsed         | 44           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0022877562 |
# |    clip_fraction        | 0.00298      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | 0.0002116561 |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.99e+03     |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00212     |
# |    std                  | 0.998        |
# |    value_loss           | 1.55e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -613         |
# | time/                   |              |
# |    fps                  | 92           |
# |    iterations           | 3            |
# |    time_elapsed         | 66           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0005998205 |
# |    clip_fraction        | 0.000293     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | 0.005589485  |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.62e+03     |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.000587    |
# |    std                  | 1            |
# |    value_loss           | 1.37e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -601         |
# | time/                   |              |
# |    fps                  | 92           |
# |    iterations           | 4            |
# |    time_elapsed         | 88           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0015505512 |
# |    clip_fraction        | 0.000342     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | 0.0035551786 |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.27e+03     |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00113     |
# |    std                  | 1            |
# |    value_loss           | 1.54e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -603         |
# | time/                   |              |
# |    fps                  | 93           |
# |    iterations           | 5            |
# |    time_elapsed         | 109          |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.002128405  |
# |    clip_fraction        | 0.00171      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | 0.0019800663 |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5e+03        |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00139     |
# |    std                  | 0.991        |
# |    value_loss           | 1.32e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -628         |
# | time/                   |              |
# |    fps                  | 94           |
# |    iterations           | 6            |
# |    time_elapsed         | 130          |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.004254423  |
# |    clip_fraction        | 0.0182       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.8         |
# |    explained_variance   | 0.0012946129 |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.01e+03     |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00385     |
# |    std                  | 0.978        |
# |    value_loss           | 1.25e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -631         |
# | time/                   |              |
# |    fps                  | 95           |
# |    iterations           | 7            |
# |    time_elapsed         | 150          |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.007420614  |
# |    clip_fraction        | 0.0564       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.77        |
# |    explained_variance   | 0.0007663965 |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.63e+03     |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00888     |
# |    std                  | 0.96         |
# |    value_loss           | 1.44e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -592         |
# | time/                   |              |
# |    fps                  | 96           |
# |    iterations           | 8            |
# |    time_elapsed         | 170          |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0068139075 |
# |    clip_fraction        | 0.0592       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.75        |
# |    explained_variance   | 0.0005942583 |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.31e+03     |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00781     |
# |    std                  | 0.958        |
# |    value_loss           | 8.7e+03      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -556         |
# | time/                   |              |
# |    fps                  | 96           |
# |    iterations           | 9            |
# |    time_elapsed         | 191          |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.006882396  |
# |    clip_fraction        | 0.0578       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.74        |
# |    explained_variance   | 0.0004941225 |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.22e+03     |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00916     |
# |    std                  | 0.95         |
# |    value_loss           | 7.2e+03      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | -496          |
# | time/                   |               |
# |    fps                  | 96            |
# |    iterations           | 10            |
# |    time_elapsed         | 211           |
# |    total_timesteps      | 20480         |
# | train/                  |               |
# |    approx_kl            | 0.009900106   |
# |    clip_fraction        | 0.0875        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.7          |
# |    explained_variance   | -0.0001244545 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.93e+03      |
# |    n_updates            | 90            |
# |    policy_gradient_loss | -0.0145       |
# |    std                  | 0.927         |
# |    value_loss           | 4.05e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | -403          |
# | time/                   |               |
# |    fps                  | 97            |
# |    iterations           | 11            |
# |    time_elapsed         | 230           |
# |    total_timesteps      | 22528         |
# | train/                  |               |
# |    approx_kl            | 0.010058461   |
# |    clip_fraction        | 0.0942        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.66         |
# |    explained_variance   | -6.055832e-05 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.51e+03      |
# |    n_updates            | 100           |
# |    policy_gradient_loss | -0.0141       |
# |    std                  | 0.91          |
# |    value_loss           | 2.7e+03       |
# -------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 100            |
# |    ep_rew_mean          | -332           |
# | time/                   |                |
# |    fps                  | 98             |
# |    iterations           | 12             |
# |    time_elapsed         | 249            |
# |    total_timesteps      | 24576          |
# | train/                  |                |
# |    approx_kl            | 0.0091001      |
# |    clip_fraction        | 0.0813         |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -2.6           |
# |    explained_variance   | -0.00013589859 |
# |    learning_rate        | 0.0003         |
# |    loss                 | 349            |
# |    n_updates            | 110            |
# |    policy_gradient_loss | -0.014         |
# |    std                  | 0.881          |
# |    value_loss           | 1.2e+03        |
# --------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | -258          |
# | time/                   |               |
# |    fps                  | 99            |
# |    iterations           | 13            |
# |    time_elapsed         | 267           |
# |    total_timesteps      | 26624         |
# | train/                  |               |
# |    approx_kl            | 0.008414988   |
# |    clip_fraction        | 0.0678        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.52         |
# |    explained_variance   | -0.0001295805 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 288           |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -0.0112       |
# |    std                  | 0.849         |
# |    value_loss           | 876           |
# -------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 100            |
# |    ep_rew_mean          | -198           |
# | time/                   |                |
# |    fps                  | 100            |
# |    iterations           | 14             |
# |    time_elapsed         | 285            |
# |    total_timesteps      | 28672          |
# | train/                  |                |
# |    approx_kl            | 0.014959713    |
# |    clip_fraction        | 0.124          |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -2.45          |
# |    explained_variance   | -0.00021898746 |
# |    learning_rate        | 0.0003         |
# |    loss                 | 239            |
# |    n_updates            | 130            |
# |    policy_gradient_loss | -0.0114        |
# |    std                  | 0.825          |
# |    value_loss           | 630            |
# --------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 100            |
# |    ep_rew_mean          | -154           |
# | time/                   |                |
# |    fps                  | 100            |
# |    iterations           | 15             |
# |    time_elapsed         | 304            |
# |    total_timesteps      | 30720          |
# | train/                  |                |
# |    approx_kl            | 0.0038145448   |
# |    clip_fraction        | 0.0869         |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -2.43          |
# |    explained_variance   | -0.00017750263 |
# |    learning_rate        | 0.0003         |
# |    loss                 | 107            |
# |    n_updates            | 140            |
# |    policy_gradient_loss | -0.00522       |
# |    std                  | 0.824          |
# |    value_loss           | 297            |
# --------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 100            |
# |    ep_rew_mean          | -119           |
# | time/                   |                |
# |    fps                  | 101            |
# |    iterations           | 16             |
# |    time_elapsed         | 321            |
# |    total_timesteps      | 32768          |
# | train/                  |                |
# |    approx_kl            | 0.0067271856   |
# |    clip_fraction        | 0.0904         |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -2.41          |
# |    explained_variance   | -7.6293945e-05 |
# |    learning_rate        | 0.0003         |
# |    loss                 | 108            |
# |    n_updates            | 150            |
# |    policy_gradient_loss | -0.00749       |
# |    std                  | 0.825          |
# |    value_loss           | 333            |
# --------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 100            |
# |    ep_rew_mean          | -92.2          |
# | time/                   |                |
# |    fps                  | 102            |
# |    iterations           | 17             |
# |    time_elapsed         | 339            |
# |    total_timesteps      | 34816          |
# | train/                  |                |
# |    approx_kl            | 0.0056875385   |
# |    clip_fraction        | 0.0778         |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -2.41          |
# |    explained_variance   | -3.8266182e-05 |
# |    learning_rate        | 0.0003         |
# |    loss                 | 51             |
# |    n_updates            | 160            |
# |    policy_gradient_loss | -0.011         |
# |    std                  | 0.82           |
# |    value_loss           | 179            |
# --------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 100            |
# |    ep_rew_mean          | -71.5          |
# | time/                   |                |
# |    fps                  | 103            |
# |    iterations           | 18             |
# |    time_elapsed         | 357            |
# |    total_timesteps      | 36864          |
# | train/                  |                |
# |    approx_kl            | 0.009623114    |
# |    clip_fraction        | 0.0564         |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -2.39          |
# |    explained_variance   | -2.6226044e-05 |
# |    learning_rate        | 0.0003         |
# |    loss                 | 79.1           |
# |    n_updates            | 170            |
# |    policy_gradient_loss | -0.00619       |
# |    std                  | 0.818          |
# |    value_loss           | 153            |
# --------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | -57.6         |
# | time/                   |               |
# |    fps                  | 103           |
# |    iterations           | 19            |
# |    time_elapsed         | 375           |
# |    total_timesteps      | 38912         |
# | train/                  |               |
# |    approx_kl            | 0.0042551486  |
# |    clip_fraction        | 0.0176        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.38         |
# |    explained_variance   | -1.847744e-05 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 36.9          |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -0.00304      |
# |    std                  | 0.816         |
# |    value_loss           | 90.9          |
# -------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 100            |
# |    ep_rew_mean          | -45.9          |
# | time/                   |                |
# |    fps                  | 104            |
# |    iterations           | 20             |
# |    time_elapsed         | 392            |
# |    total_timesteps      | 40960          |
# | train/                  |                |
# |    approx_kl            | 0.0057977038   |
# |    clip_fraction        | 0.0397         |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -2.37          |
# |    explained_variance   | -1.4901161e-05 |
# |    learning_rate        | 0.0003         |
# |    loss                 | 40.6           |
# |    n_updates            | 190            |
# |    policy_gradient_loss | -0.00538       |
# |    std                  | 0.81           |
# |    value_loss           | 92.6           |
# --------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 100            |
# |    ep_rew_mean          | -36.1          |
# | time/                   |                |
# |    fps                  | 104            |
# |    iterations           | 21             |
# |    time_elapsed         | 409            |
# |    total_timesteps      | 43008          |
# | train/                  |                |
# |    approx_kl            | 0.005373964    |
# |    clip_fraction        | 0.0419         |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -2.36          |
# |    explained_variance   | -1.4305115e-05 |
# |    learning_rate        | 0.0003         |
# |    loss                 | 15.5           |
# |    n_updates            | 200            |
# |    policy_gradient_loss | -0.00677       |
# |    std                  | 0.808          |
# |    value_loss           | 77.1           |
# --------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 100            |
# |    ep_rew_mean          | -24.1          |
# | time/                   |                |
# |    fps                  | 105            |
# |    iterations           | 22             |
# |    time_elapsed         | 426            |
# |    total_timesteps      | 45056          |
# | train/                  |                |
# |    approx_kl            | 0.005634066    |
# |    clip_fraction        | 0.0256         |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -2.35          |
# |    explained_variance   | -2.2411346e-05 |
# |    learning_rate        | 0.0003         |
# |    loss                 | 32.7           |
# |    n_updates            | 210            |
# |    policy_gradient_loss | -0.00339       |
# |    std                  | 0.799          |
# |    value_loss           | 71.8           |
# --------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 100            |
# |    ep_rew_mean          | -21.3          |
# | time/                   |                |
# |    fps                  | 106            |
# |    iterations           | 23             |
# |    time_elapsed         | 443            |
# |    total_timesteps      | 47104          |
# | train/                  |                |
# |    approx_kl            | 0.0030178593   |
# |    clip_fraction        | 0.0142         |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -2.33          |
# |    explained_variance   | 1.41859055e-05 |
# |    learning_rate        | 0.0003         |
# |    loss                 | 11.6           |
# |    n_updates            | 220            |
# |    policy_gradient_loss | -0.00161       |
# |    std                  | 0.797          |
# |    value_loss           | 45.5           |
# --------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | -14.5         |
# | time/                   |               |
# |    fps                  | 106           |
# |    iterations           | 24            |
# |    time_elapsed         | 461           |
# |    total_timesteps      | 49152         |
# | train/                  |               |
# |    approx_kl            | 0.012772629   |
# |    clip_fraction        | 0.0508        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.31         |
# |    explained_variance   | -8.702278e-06 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 7.7           |
# |    n_updates            | 230           |
# |    policy_gradient_loss | -0.00196      |
# |    std                  | 0.788         |
# |    value_loss           | 34.5          |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -10.6       |
# | time/                   |             |
# |    fps                  | 106         |
# |    iterations           | 25          |
# |    time_elapsed         | 482         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.003932899 |
# |    clip_fraction        | 0.0846      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.29       |
# |    explained_variance   | 9.23872e-06 |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.94        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | 0.00309     |
# |    std                  | 0.787       |
# |    value_loss           | 21.8        |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | -6.16         |
# | time/                   |               |
# |    fps                  | 106           |
# |    iterations           | 26            |
# |    time_elapsed         | 499           |
# |    total_timesteps      | 53248         |
# | train/                  |               |
# |    approx_kl            | 0.004961809   |
# |    clip_fraction        | 0.0393        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.29         |
# |    explained_variance   | 4.7385693e-05 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.43          |
# |    n_updates            | 250           |
# |    policy_gradient_loss | -5.61e-05     |
# |    std                  | 0.789         |
# |    value_loss           | 14.5          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -4.68        |
# | time/                   |              |
# |    fps                  | 107          |
# |    iterations           | 27           |
# |    time_elapsed         | 515          |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.010683207  |
# |    clip_fraction        | 0.0447       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.29        |
# |    explained_variance   | 8.332729e-05 |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.932        |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.000263    |
# |    std                  | 0.786        |
# |    value_loss           | 12           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -1.76        |
# | time/                   |              |
# |    fps                  | 107          |
# |    iterations           | 28           |
# |    time_elapsed         | 531          |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.008340506  |
# |    clip_fraction        | 0.0606       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.29        |
# |    explained_variance   | 7.623434e-05 |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.919        |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00125     |
# |    std                  | 0.791        |
# |    value_loss           | 8.53         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | -1.06         |
# | time/                   |               |
# |    fps                  | 107           |
# |    iterations           | 29            |
# |    time_elapsed         | 551           |
# |    total_timesteps      | 59392         |
# | train/                  |               |
# |    approx_kl            | 0.0018053553  |
# |    clip_fraction        | 0.0159        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.29         |
# |    explained_variance   | 2.2172928e-05 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.765         |
# |    n_updates            | 280           |
# |    policy_gradient_loss | 0.000848      |
# |    std                  | 0.792         |
# |    value_loss           | 6.34          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | -0.513        |
# | time/                   |               |
# |    fps                  | 108           |
# |    iterations           | 30            |
# |    time_elapsed         | 567           |
# |    total_timesteps      | 61440         |
# | train/                  |               |
# |    approx_kl            | 0.002037269   |
# |    clip_fraction        | 0.0241        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.3          |
# |    explained_variance   | 1.2695789e-05 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.05          |
# |    n_updates            | 290           |
# |    policy_gradient_loss | 0.00108       |
# |    std                  | 0.8           |
# |    value_loss           | 4.49          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | -0.949        |
# | time/                   |               |
# |    fps                  | 108           |
# |    iterations           | 31            |
# |    time_elapsed         | 583           |
# |    total_timesteps      | 63488         |
# | train/                  |               |
# |    approx_kl            | 0.0053375345  |
# |    clip_fraction        | 0.0274        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.31         |
# |    explained_variance   | 0.00011861324 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.286         |
# |    n_updates            | 300           |
# |    policy_gradient_loss | -0.00102      |
# |    std                  | 0.806         |
# |    value_loss           | 2.42          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | -1.3          |
# | time/                   |               |
# |    fps                  | 108           |
# |    iterations           | 32            |
# |    time_elapsed         | 603           |
# |    total_timesteps      | 65536         |
# | train/                  |               |
# |    approx_kl            | 0.0028482818  |
# |    clip_fraction        | 0.0284        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.32         |
# |    explained_variance   | 1.4364719e-05 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.567         |
# |    n_updates            | 310           |
# |    policy_gradient_loss | -0.000233     |
# |    std                  | 0.803         |
# |    value_loss           | 2.03          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | -1.36         |
# | time/                   |               |
# |    fps                  | 108           |
# |    iterations           | 33            |
# |    time_elapsed         | 621           |
# |    total_timesteps      | 67584         |
# | train/                  |               |
# |    approx_kl            | 0.0024093622  |
# |    clip_fraction        | 0.0533        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.31         |
# |    explained_variance   | 1.9192696e-05 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.85          |
# |    n_updates            | 320           |
# |    policy_gradient_loss | -0.00171      |
# |    std                  | 0.802         |
# |    value_loss           | 2.21          |
# -------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 100            |
# |    ep_rew_mean          | -1.06          |
# | time/                   |                |
# |    fps                  | 109            |
# |    iterations           | 34             |
# |    time_elapsed         | 638            |
# |    total_timesteps      | 69632          |
# | train/                  |                |
# |    approx_kl            | 0.0049187047   |
# |    clip_fraction        | 0.0376         |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -2.31          |
# |    explained_variance   | -2.4318695e-05 |
# |    learning_rate        | 0.0003         |
# |    loss                 | 0.214          |
# |    n_updates            | 330            |
# |    policy_gradient_loss | -0.00182       |
# |    std                  | 0.811          |
# |    value_loss           | 2.6            |
# --------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | -1.22         |
# | time/                   |               |
# |    fps                  | 109           |
# |    iterations           | 35            |
# |    time_elapsed         | 656           |
# |    total_timesteps      | 71680         |
# | train/                  |               |
# |    approx_kl            | 0.0058075953  |
# |    clip_fraction        | 0.0415        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.33         |
# |    explained_variance   | 0.00019055605 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.102         |
# |    n_updates            | 340           |
# |    policy_gradient_loss | -0.0039       |
# |    std                  | 0.823         |
# |    value_loss           | 0.53          |
# -------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 100            |
# |    ep_rew_mean          | -0.874         |
# | time/                   |                |
# |    fps                  | 109            |
# |    iterations           | 36             |
# |    time_elapsed         | 673            |
# |    total_timesteps      | 73728          |
# | train/                  |                |
# |    approx_kl            | 0.005729774    |
# |    clip_fraction        | 0.026          |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -2.35          |
# |    explained_variance   | -2.9802322e-06 |
# |    learning_rate        | 0.0003         |
# |    loss                 | 0.0948         |
# |    n_updates            | 350            |
# |    policy_gradient_loss | 0.000331       |
# |    std                  | 0.826          |
# |    value_loss           | 1.43           |
# --------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | -0.874        |
# | time/                   |               |
# |    fps                  | 110           |
# |    iterations           | 37            |
# |    time_elapsed         | 688           |
# |    total_timesteps      | 75776         |
# | train/                  |               |
# |    approx_kl            | 0.0017399875  |
# |    clip_fraction        | 0.03          |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.36         |
# |    explained_variance   | 4.4345856e-05 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0687        |
# |    n_updates            | 360           |
# |    policy_gradient_loss | 0.001         |
# |    std                  | 0.835         |
# |    value_loss           | 0.473         |
# -------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 100            |
# |    ep_rew_mean          | -0.424         |
# | time/                   |                |
# |    fps                  | 110            |
# |    iterations           | 38             |
# |    time_elapsed         | 706            |
# |    total_timesteps      | 77824          |
# | train/                  |                |
# |    approx_kl            | 0.006069281    |
# |    clip_fraction        | 0.0218         |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -2.37          |
# |    explained_variance   | 1.21593475e-05 |
# |    learning_rate        | 0.0003         |
# |    loss                 | 0.107          |
# |    n_updates            | 370            |
# |    policy_gradient_loss | 5.14e-05       |
# |    std                  | 0.827          |
# |    value_loss           | 1.02           |
# --------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | -0.724        |
# | time/                   |               |
# |    fps                  | 110           |
# |    iterations           | 39            |
# |    time_elapsed         | 722           |
# |    total_timesteps      | 79872         |
# | train/                  |               |
# |    approx_kl            | 0.005946531   |
# |    clip_fraction        | 0.0733        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.35         |
# |    explained_variance   | 0.00033801794 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0177        |
# |    n_updates            | 380           |
# |    policy_gradient_loss | -0.00356      |
# |    std                  | 0.822         |
# |    value_loss           | 0.12          |
# -------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 100            |
# |    ep_rew_mean          | -0.864         |
# | time/                   |                |
# |    fps                  | 110            |
# |    iterations           | 40             |
# |    time_elapsed         | 739            |
# |    total_timesteps      | 81920          |
# | train/                  |                |
# |    approx_kl            | 0.005933434    |
# |    clip_fraction        | 0.0521         |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -2.34          |
# |    explained_variance   | -4.4107437e-06 |
# |    learning_rate        | 0.0003         |
# |    loss                 | 0.343          |
# |    n_updates            | 390            |
# |    policy_gradient_loss | 0.0008         |
# |    std                  | 0.822          |
# |    value_loss           | 1.18           |
# --------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 100            |
# |    ep_rew_mean          | -0.814         |
# | time/                   |                |
# |    fps                  | 111            |
# |    iterations           | 41             |
# |    time_elapsed         | 755            |
# |    total_timesteps      | 83968          |
# | train/                  |                |
# |    approx_kl            | 0.0020136312   |
# |    clip_fraction        | 0.0316         |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -2.33          |
# |    explained_variance   | -2.8014183e-05 |
# |    learning_rate        | 0.0003         |
# |    loss                 | 2.23           |
# |    n_updates            | 400            |
# |    policy_gradient_loss | -0.00138       |
# |    std                  | 0.821          |
# |    value_loss           | 2.15           |
# --------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -0.9         |
# | time/                   |              |
# |    fps                  | 111          |
# |    iterations           | 42           |
# |    time_elapsed         | 771          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0071311933 |
# |    clip_fraction        | 0.0701       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.33        |
# |    explained_variance   | 9.006262e-05 |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0116       |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00448     |
# |    std                  | 0.82         |
# |    value_loss           | 0.146        |
# ------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 100            |
# |    ep_rew_mean          | -0.729         |
# | time/                   |                |
# |    fps                  | 111            |
# |    iterations           | 43             |
# |    time_elapsed         | 789            |
# |    total_timesteps      | 88064          |
# | train/                  |                |
# |    approx_kl            | 0.0025067255   |
# |    clip_fraction        | 0.0554         |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -2.33          |
# |    explained_variance   | -3.3020973e-05 |
# |    learning_rate        | 0.0003         |
# |    loss                 | 0.122          |
# |    n_updates            | 420            |
# |    policy_gradient_loss | -0.00185       |
# |    std                  | 0.818          |
# |    value_loss           | 0.306          |
# --------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | -0.929        |
# | time/                   |               |
# |    fps                  | 111           |
# |    iterations           | 44            |
# |    time_elapsed         | 810           |
# |    total_timesteps      | 90112         |
# | train/                  |               |
# |    approx_kl            | 0.0043030903  |
# |    clip_fraction        | 0.0437        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.33         |
# |    explained_variance   | 0.00036793947 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00916       |
# |    n_updates            | 430           |
# |    policy_gradient_loss | -0.00131      |
# |    std                  | 0.823         |
# |    value_loss           | 0.0376        |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | -0.679        |
# | time/                   |               |
# |    fps                  | 111           |
# |    iterations           | 45            |
# |    time_elapsed         | 827           |
# |    total_timesteps      | 92160         |
# | train/                  |               |
# |    approx_kl            | 0.004723713   |
# |    clip_fraction        | 0.0431        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.33         |
# |    explained_variance   | -2.193451e-05 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.288         |
# |    n_updates            | 440           |
# |    policy_gradient_loss | 2.19e-05      |
# |    std                  | 0.815         |
# |    value_loss           | 1.85          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | -0.729        |
# | time/                   |               |
# |    fps                  | 111           |
# |    iterations           | 46            |
# |    time_elapsed         | 842           |
# |    total_timesteps      | 94208         |
# | train/                  |               |
# |    approx_kl            | 0.00273797    |
# |    clip_fraction        | 0.0274        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.32         |
# |    explained_variance   | -9.298325e-06 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.179         |
# |    n_updates            | 450           |
# |    policy_gradient_loss | 0.000814      |
# |    std                  | 0.813         |
# |    value_loss           | 0.849         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | -0.579        |
# | time/                   |               |
# |    fps                  | 111           |
# |    iterations           | 47            |
# |    time_elapsed         | 863           |
# |    total_timesteps      | 96256         |
# | train/                  |               |
# |    approx_kl            | 0.0056076     |
# |    clip_fraction        | 0.0598        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.33         |
# |    explained_variance   | 0.00043284893 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0105        |
# |    n_updates            | 460           |
# |    policy_gradient_loss | -0.00196      |
# |    std                  | 0.823         |
# |    value_loss           | 0.0134        |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | -0.4          |
# | time/                   |               |
# |    fps                  | 111           |
# |    iterations           | 48            |
# |    time_elapsed         | 879           |
# |    total_timesteps      | 98304         |
# | train/                  |               |
# |    approx_kl            | 0.0040988913  |
# |    clip_fraction        | 0.0342        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.35         |
# |    explained_variance   | 0.00054585934 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0124        |
# |    n_updates            | 470           |
# |    policy_gradient_loss | -0.000175     |
# |    std                  | 0.826         |
# |    value_loss           | 0.00874       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | -0.3         |
# | time/                   |              |
# |    fps                  | 112          |
# |    iterations           | 49           |
# |    time_elapsed         | 895          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0057836124 |
# |    clip_fraction        | 0.0401       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.36        |
# |    explained_variance   | 0.0006199479 |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0168       |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00163     |
# |    std                  | 0.829        |
# |    value_loss           | 0.00638      |
# ------------------------------------------

# %%
from datetime import datetime

# Save the trained model
timestamp = datetime.now().strftime("%Y%m%d-%H%M%S")  # Add timestamp to avoid overwriting
model.save(f"ppo_smart_city_env_model_{timestamp}")

# %%
# show training progress
# %load_ext tensorboard
# %tensorboard --logdir results_sb
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Reusing TensorBoard on port 6006 (pid 2171), started 0:01:12 ago. (Use '!kill 2171' to kill it.)
#       <iframe id="tensorboard-frame-804035935daf306d" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-804035935daf306d");
#           const url = new URL("http://localhost");
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
